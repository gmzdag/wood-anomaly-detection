# %% [markdown]
# # CFA

# %% [markdown]
# Bu notebook'ta, ahşap yüzeylerdeki anomalileri tespit etmek için bir *CFA* modeli geliştirilecek ve eğitilecektir.

# %% [markdown]
# ## 1. Ortam Kurulumu

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !mkdir CFA
# %cd /content/drive/MyDrive/CFA
# Out:
# mkdir: cannot create directory ‘CFA’: File exists
# /content/drive/MyDrive/CFA

# %% [markdown]
# ## 2. Gerekli Kütüphanelerin Kurulumu ve İçe Aktarımı

# %%
# !pip install anomalib[full]
# Out:
# Requirement already satisfied: anomalib[full] in /usr/local/lib/python3.11/dist-packages (2.0.0)
# Requirement already satisfied: omegaconf>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2.3.0)
# Requirement already satisfied: rich>=13.5.2 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (13.9.4)
# Requirement already satisfied: jsonargparse>=4.27.7 in /usr/local/lib/python3.11/dist-packages (from jsonargparse[signatures]>=4.27.7->anomalib[full]) (4.40.0)
# Requirement already satisfied: docstring_parser in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (0.16)
# Requirement already satisfied: rich_argparse in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (1.7.0)
# Requirement already satisfied: lightning-utilities in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (0.14.3)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.11/dist-packages (from jsonargparse>=4.27.7->jsonargparse[signatures]>=4.27.7->anomalib[full]) (6.0.2)
# Requirement already satisfied: typeshed-client>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from jsonargparse[signatures]>=4.27.7->anomalib[full]) (2.7.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from omegaconf>=2.1.1->anomalib[full]) (4.9.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.5.2->anomalib[full]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.5.2->anomalib[full]) (2.19.1)
# Requirement already satisfied: av>=10.0.0 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (14.4.0)
# Requirement already satisfied: einops>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (0.8.1)
# Requirement already satisfied: freia>=0.2 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (0.2)
# Requirement already satisfied: kornia>=0.6.6 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (0.8.1)
# Requirement already satisfied: matplotlib>=3.4.3 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (3.10.0)
# Requirement already satisfied: opencv-python>=4.5.3.56 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (4.11.0.86)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2.2.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (0.25.2)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2025.5.10)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (1.0.15)
# Requirement already satisfied: lightning>=2.2 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2.5.1.post0)
# Requirement already satisfied: torch>=2 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2.6.0+cu124)
# Requirement already satisfied: torchmetrics>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (1.7.1)
# Requirement already satisfied: open-clip-torch<2.26.1,>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2.24.0)
# Requirement already satisfied: openvino>=2024.0 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2025.1.0)
# Requirement already satisfied: nncf>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2.16.0)
# Requirement already satisfied: onnx>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (1.18.0)
# Requirement already satisfied: ollama>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (0.4.8)
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (1.78.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (1.1.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (4.51.3)
# Requirement already satisfied: comet-ml>=3.31.7 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (3.49.10)
# Requirement already satisfied: gradio>=4 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (5.29.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2.18.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (0.19.11)
# Requirement already satisfied: mlflow>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (2.22.0)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (3.1.44)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (7.7.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.11/dist-packages (from anomalib[full]) (6.5.7)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.11/dist-packages (from lightning-utilities->anomalib[full]) (24.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities->anomalib[full]) (75.2.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from lightning-utilities->anomalib[full]) (4.13.2)
# Requirement already satisfied: dulwich!=0.20.33,>=0.20.6 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (0.22.8)
# Requirement already satisfied: everett<3.2.0,>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml>=3.31.7->anomalib[full]) (3.1.0)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (4.23.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (5.9.5)
# Requirement already satisfied: python-box<7.0.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (6.1.0)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (2.32.3)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (2.28.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (3.20.1)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (1.17.2)
# Requirement already satisfied: wurlitzer>=1.0.2 in /usr/local/lib/python3.11/dist-packages (from comet-ml>=3.31.7->anomalib[full]) (3.1.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.11/dist-packages (from freia>=0.2->anomalib[full]) (2.0.2)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.11/dist-packages (from freia>=0.2->anomalib[full]) (1.15.3)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.115.12)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.5.0)
# Requirement already satisfied: gradio-client==1.10.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (1.10.1)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.31.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (3.10.18)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (11.2.1)
# Requirement already satisfied: pydantic<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (2.11.4)
# Requirement already satisfied: pydub in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.11.10)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.1.6)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.15.3)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from gradio>=4->anomalib[full]) (0.34.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.1->gradio>=4->anomalib[full]) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in /usr/local/lib/python3.11/dist-packages (from gradio-client==1.10.1->gradio>=4->anomalib[full]) (15.0.1)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.11/dist-packages (from kornia>=0.6.6->anomalib[full]) (0.1.9)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning>=2.2->anomalib[full]) (4.67.1)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.11/dist-packages (from lightning>=2.2->anomalib[full]) (2.5.1.post0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.5.2->anomalib[full]) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.3->anomalib[full]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.3->anomalib[full]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.3->anomalib[full]) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.3->anomalib[full]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.3->anomalib[full]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.4.3->anomalib[full]) (2.9.0.post0)
# Requirement already satisfied: mlflow-skinny==2.22.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (2.22.0)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (3.1.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (1.15.2)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (7.1.0)
# Requirement already satisfied: graphene<4 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (3.4.3)
# Requirement already satisfied: gunicorn<24 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (23.0.0)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (3.8)
# Requirement already satisfied: pyarrow<20,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (18.1.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (1.6.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow>=1.0.0->anomalib[full]) (2.0.40)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (8.2.0)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (3.1.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (0.53.0)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (1.33.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (1.33.1)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (5.29.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (0.5.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython->anomalib[full]) (4.0.12)
# Requirement already satisfied: jstyleson>=0.0.2 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (0.0.2)
# Requirement already satisfied: natsort>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (8.4.0)
# Requirement already satisfied: networkx<3.5.0,>=2.6 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (3.4.2)
# Requirement already satisfied: ninja<1.12,>=1.10.0.post2 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (1.11.1.4)
# Requirement already satisfied: openvino-telemetry>=2023.2.0 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (2025.1.0)
# Requirement already satisfied: pydot<=3.0.4,>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (3.0.4)
# Requirement already satisfied: pymoo>=0.6.0.1 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (0.6.1.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (0.5.3)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from nncf>=2.10.0->anomalib[full]) (0.9.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from open-clip-torch<2.26.1,>=2.23.0->anomalib[full]) (0.21.0+cu124)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from open-clip-torch<2.26.1,>=2.23.0->anomalib[full]) (2024.11.6)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from open-clip-torch<2.26.1,>=2.23.0->anomalib[full]) (6.3.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from open-clip-torch<2.26.1,>=2.23.0->anomalib[full]) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.0->anomalib[full]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.0->anomalib[full]) (2025.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (3.18.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2->anomalib[full]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2->anomalib[full]) (1.3.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from typeshed-client>=2.3.0->jsonargparse[signatures]>=4.27.7->anomalib[full]) (6.5.2)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->anomalib[full]) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->anomalib[full]) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.11/dist-packages (from ipykernel->anomalib[full]) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->anomalib[full]) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from ipykernel->anomalib[full]) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from ipykernel->anomalib[full]) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from ipykernel->anomalib[full]) (6.4.2)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel->anomalib[full]) (5.7.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->anomalib[full]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->anomalib[full]) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets->anomalib[full]) (3.0.15)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook->anomalib[full]) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.11/dist-packages (from notebook->anomalib[full]) (5.7.2)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.11/dist-packages (from notebook->anomalib[full]) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook->anomalib[full]) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook->anomalib[full]) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook->anomalib[full]) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook->anomalib[full]) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook->anomalib[full]) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai->anomalib[full]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai->anomalib[full]) (0.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai->anomalib[full]) (1.3.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image->anomalib[full]) (2.37.0)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->anomalib[full]) (0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->anomalib[full]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->anomalib[full]) (1.71.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->anomalib[full]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->anomalib[full]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->anomalib[full]) (3.1.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers->anomalib[full]) (0.21.1)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb->anomalib[full]) (0.4.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->anomalib[full]) (4.3.8)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->anomalib[full]) (1.3.6)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow>=1.0.0->anomalib[full]) (1.1.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5.0,>=3.0->gradio>=4->anomalib[full]) (3.10)
# Requirement already satisfied: configobj in /usr/local/lib/python3.11/dist-packages (from everett[ini]<3.2.0,>=1.0.1->comet-ml>=3.31.7->anomalib[full]) (5.0.9)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow>=1.0.0->anomalib[full]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow>=1.0.0->anomalib[full]) (2.2.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2->anomalib[full]) (3.11.15)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython->anomalib[full]) (5.0.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow>=1.0.0->anomalib[full]) (3.2.6)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow>=1.0.0->anomalib[full]) (3.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio>=4->anomalib[full]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.24.1->gradio>=4->anomalib[full]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=4->anomalib[full]) (0.16.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->anomalib[full]) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->anomalib[full]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->anomalib[full]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->anomalib[full]) (3.0.51)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->anomalib[full]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=7.23.1->ipykernel->anomalib[full]) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.31.7->anomalib[full]) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.31.7->anomalib[full]) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.31.7->anomalib[full]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet-ml>=3.31.7->anomalib[full]) (0.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook->anomalib[full]) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->anomalib[full]) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->anomalib[full]) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->anomalib[full]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->anomalib[full]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->anomalib[full]) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->anomalib[full]) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook->anomalib[full]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat->notebook->anomalib[full]) (2.21.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio>=4->anomalib[full]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio>=4->anomalib[full]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<2.12,>=2.0->gradio>=4->anomalib[full]) (0.4.0)
# Requirement already satisfied: autograd>=1.4 in /usr/local/lib/python3.11/dist-packages (from pymoo>=0.6.0.1->nncf>=2.10.0->anomalib[full]) (1.8.0)
# Requirement already satisfied: cma==3.2.2 in /usr/local/lib/python3.11/dist-packages (from pymoo>=0.6.0.1->nncf>=2.10.0->anomalib[full]) (3.2.2)
# Requirement already satisfied: alive-progress in /usr/local/lib/python3.11/dist-packages (from pymoo>=0.6.0.1->nncf>=2.10.0->anomalib[full]) (3.2.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from pymoo>=0.6.0.1->nncf>=2.10.0->anomalib[full]) (0.3.7)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.11/dist-packages (from pymoo>=0.6.0.1->nncf>=2.10.0->anomalib[full]) (1.2.18)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.18.4->comet-ml>=3.31.7->anomalib[full]) (3.4.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow>=1.0.0->anomalib[full]) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow>=1.0.0->anomalib[full]) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow>=1.0.0->anomalib[full]) (3.2.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.11/dist-packages (from terminado>=0.8.3->notebook->anomalib[full]) (0.7.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0,>=0.12->gradio>=4->anomalib[full]) (1.5.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook->anomalib[full]) (21.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->open-clip-torch<2.26.1,>=2.23.0->anomalib[full]) (0.2.13)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2->anomalib[full]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2->anomalib[full]) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2->anomalib[full]) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2->anomalib[full]) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2->anomalib[full]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning>=2.2->anomalib[full]) (1.20.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook->anomalib[full]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook->anomalib[full]) (1.4.0)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (2.38.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (3.21.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->anomalib[full]) (0.8.4)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->anomalib[full]) (1.16.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (0.54b1)
# Requirement already satisfied: about-time==4.2.1 in /usr/local/lib/python3.11/dist-packages (from alive-progress->pymoo>=0.6.0.1->nncf>=2.10.0->anomalib[full]) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in /usr/local/lib/python3.11/dist-packages (from alive-progress->pymoo>=0.6.0.1->nncf>=2.10.0->anomalib[full]) (0.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->anomalib[full]) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook->anomalib[full]) (2.7)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->anomalib[full]) (2.22)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (4.9.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook->anomalib[full]) (1.8.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.22.0->mlflow>=1.0.0->anomalib[full]) (0.6.1)

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2
from PIL import Image

#Anomalib'den gerekli modüller
from anomalib.data import Folder
from anomalib.models import Cfa
from anomalib.engine import Engine
from pytorch_lightning.loggers import CSVLogger
from torch.utils.data import Dataset, DataLoader
from anomalib.metrics import Evaluator, AnomalibMetric
from anomalib.metrics.threshold import F1AdaptiveThreshold, ManualThreshold
from torchmetrics.classification import BinaryF1Score, BinaryRecall,BinaryAccuracy, BinaryPrecision
# Out:
# /usr/local/lib/python3.11/dist-packages/openvino/runtime/__init__.py:10: DeprecationWarning: The `openvino.runtime` module is deprecated and will be removed in the 2026.0 release. Please replace `openvino.runtime` with `openvino`.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %% [markdown]
# ## 3. Veriseti  Yapılandırması

# %% [markdown]
# Anomalib'in veri modüllerini kullanarak veri setini Cfa modeline uygun hale getirme. `Folder` modülü kullanılarak klasör yapısına dayalı bir veri seti tanımlanır.
#
# **Parametre Açıklamaları:**
# - `name`: Veri setine verilen isim.
# - `root`: Veri setinin ana dizini.
# - `normal_dir`: Eğitim için normal görüntülerin bulunduğu alt dizin.
# - `normal_test_dir`: Test için normal görüntülerin bulunduğu alt dizin.
# - `mask_dir`: Anomali maskelerinin bulunduğu alt dizin.
# - `abnormal_dir`: Test için anormal görüntülerin bulunduğu alt dizin.
# - `test_split_mode`: Test verisinin nasıl ayrılacağını belirtir ('from_dir' klasör yapısına göre).
# - `train_batch_size`: Eğitim batch boyutu.
# - `eval_batch_size`: Değerlendirme/Test batch boyutu.
# - `num_workers`: Veri yükleme için kullanılacak alt işlem sayısı.

# %%
DATASET_PATH = "/content/drive/MyDrive/processed_dataset/wood" #Veri Setinin Kök Dizini

# %%
datamodule = Folder(
    name = "wood_dataset",
    root = DATASET_PATH,
    normal_dir="train/good",
    normal_test_dir="test/good",
    mask_dir="ground_truth/defect",
    abnormal_dir="test/defect",
    test_split_mode= "from_dir",

    train_batch_size=8,
    eval_batch_size=8,
    num_workers=2,
)

# %% [markdown]
# ##4. Metrik Yapılandırması

# %% [markdown]
# Modelin performansını değerlendirmek için kullanılacak metriklerin tanımlaanması. Anomalib'in `Evaluator`'ı bu metrikleri test sırasında otomatik olarak hesaplayacaktır.
# Özel metrik sınıfları, PyTorch-Lightning'in `torchmetrics`'i ile Anomalib'in `AnomalibMetric`'ini birleştirir.

# %%
class Accuracy(AnomalibMetric, BinaryAccuracy):
    pass

class F1Score(AnomalibMetric, BinaryF1Score):
    pass

class Recall(AnomalibMetric, BinaryRecall):
    pass

class Precision(AnomalibMetric, BinaryPrecision):
    pass

binary_accuracy = Accuracy(fields=["pred_label", "gt_label"])
binary_f1_score = F1Score(fields=["pred_label", "gt_label"])
binary_recall = Recall(fields=["pred_label", "gt_label"])
binary_precision = Precision(fields=["pred_label", "gt_label"])

threshold_metrics = [
    F1AdaptiveThreshold(fields=["pred_score", "gt_label"]),  # Otomatik eşik
    ManualThreshold(default_value=0.5),  # 0.5 eşik değeri
    ManualThreshold(default_value=0.3),  # 0.3 eşik değeri
    ManualThreshold(default_value=0.7)   # 0.7 eşik değeri
]
metrics = [
    binary_accuracy,
    binary_f1_score,
    binary_recall,
    binary_precision,

]


evaluator = Evaluator(test_metrics=metrics)

# %% [markdown]
# ## 5. Model Yapılandırması ve Eğitimi

# %% [markdown]
# Cfa modelini tanımlanamsı ve PyTorch Lightning tabanlı `Engine` kullanarak eğitim sürecinin yönetilmesi.

# %% [markdown]
# **Model Parametreleri:**
# - `backbone`: Modelin temelini oluşturan önceden eğitilmiş ağ ('wide_resnet50_2').
# - `visualizer`: Eğitim veya test sırasında görselleştirmelerin yapılıp yapılmayacağı.
# - `evaluator`: Test sırasında kullanılacak metrikleri içeren Evaluator nesnesi.
#
# **Engine Parametreleri:**
# - `max_epochs`: Eğitimin kaç epoch süreceği.
# - `logger`: Eğitim loglarının kaydedileceği logger (CSVLogger veya TensorBoardLogger gibi).

# %%
model = Cfa(
    backbone = "wide_resnet50_2",
    visualizer=True,
    evaluator=evaluator
)

logger = CSVLogger(save_dir="/content/drive/MyDrive/CFA", name = "Cfa_logs")
# Out:
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/utilities/parsing.py:209: Attribute 'evaluator' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['evaluator'])`.
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Wide_ResNet50_2_Weights.IMAGENET1K_V1`. You can also use `weights=Wide_ResNet50_2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# ### 5.1 30 Epoch İle Eğitim

# %%
engine = Engine(max_epochs = 30, logger = logger)

engine.fit(model, datamodule=datamodule)
predictions = engine.predict(model, datamodule=datamodule)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:You are using a CUDA device ('NVIDIA A100-SXM4-40GB') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name           | Type          | Params | Mode
# ---------------------------------------------------------
# 0 | pre_processor  | PreProcessor  | 0      | train
# 1 | post_processor | PostProcessor | 0      | train
# 2 | evaluator      | Evaluator     | 0      | train
# 3 | model          | CfaModel      | 31.3 M | train
# 4 | loss           | CfaLoss       | 0      | train
# ---------------------------------------------------------
# 31.3 M    Trainable params
# 0         Non-trainable params
# 31.3 M    Total params
# 125.169   Total estimated model params size (MB)
# 22        Modules in train mode
# 121       Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name           | Type          | Params | Mode
# ---------------------------------------------------------
# 0 | pre_processor  | PreProcessor  | 0      | train
# 1 | post_processor | PostProcessor | 0      | train
# 2 | evaluator      | Evaluator     | 0      | train
# 3 | model          | CfaModel      | 31.3 M | train
# 4 | loss           | CfaLoss       | 0      | train
# ---------------------------------------------------------
# 31.3 M    Trainable params
# 0         Non-trainable params
# 31.3 M    Total params
# 125.169   Total estimated model params size (MB)
# 22        Modules in train mode
# 121       Modules in eval mode
# /usr/local/lib/python3.11/dist-packages/pytorch_lightning/core/saving.py:363: Skipping 'evaluator' parameter because it is not possible to safely dump to YAML.
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py:310: The number of training batches (9) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
# Training: |          | 0/? [00:00<?, ?it/s]
#   0%|          | 0/9 [00:00<?, ?it/s]
#  11%|█         | 1/9 [00:00<00:03,  2.09it/s]
#  56%|█████▌    | 5/9 [00:00<00:00, 10.33it/s]
# 100%|██████████| 9/9 [00:00<00:00, 12.16it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=30` reached.
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# INFO:pytorch_lightning.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]

# %%
test_results = engine.test(model, datamodule=datamodule)
print("Test Sonuçları:", test_results)
# Out:
# INFO:pytorch_lightning.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         Accuracy          │    0.6760563254356384     │
# │          F1Score          │     0.75789475440979      │
# │         Precision         │    0.6101694703102112     │
# │          Recall           │            1.0            │
# └───────────────────────────┴───────────────────────────┘
# Test Sonuçları: [{'Accuracy': 0.6760563254356384, 'F1Score': 0.75789475440979, 'Recall': 1.0, 'Precision': 0.6101694703102112}]

# %%
save_path = "/content/drive/MyDrive/CFA/cfa_model.pth"
torch.save(model.state_dict(), save_path)
print(f"Model ağırlıkları '{save_path}' dosyasına kaydedildi.")

# %% [markdown]
# ## 6. Performans Değerlendirmesi ve Görselleştirme

# %% [markdown]
# Modelin tahmin ettiği anomali haritaları kullanılarak optimal bir piksel eşiği hesaplanmakta, bu eşik kullanılarak ikili maskeler oluşturulmakta ve bu tahmin edilen maskeler gerçek (Ground Truth) maskelerle karşılaştırılarak IoU (Intersection over Union) değerleri hesaplanmakta ve görselleştirilmektedir.

# %%
from anomalib.metrics.threshold import F1AdaptiveThreshold
import cv2
import numpy as np
from PIL import Image


f1_threshold_finder = F1AdaptiveThreshold(fields=["anomaly_map", "gt_mask"])

all_predictions_batches = engine.predict(model, datamodule=datamodule)


processed_batches_for_threshold = 0
for batch_item in all_predictions_batches:
    if batch_item.gt_mask is not None and hasattr(batch_item, 'anomaly_map') and batch_item.anomaly_map is not None:
         try:
            f1_threshold_finder.update(batch_item)
            processed_batches_for_threshold += 1
         except Exception as e:
             print(f"Uyarı: Bir batch işlenirken hata oluştu (Eşik update): {e}. Batch atlanıyor.")


try:
    computed_f1_threshold = f1_threshold_finder.compute()
    print(f"\nF1AdaptiveThreshold ile Hesaplanan Optimal Piksel Eşiği: {computed_f1_threshold.item():.4f}")
except Exception as e:
     print(f"\n!!! Hata: F1AdaptiveThreshold compute() metodunda hata oluştu: {e}")
     print("!!! Geçici olarak varsayılan 0.5 eşiği kullanılacaktır.")
     computed_f1_threshold = torch.tensor(0.5)

optimal_threshold = computed_f1_threshold.item()


# İki ikili maske arasındaki IoU'yu hesaplayan fonksiyon
def calculate_iou(mask1, mask2):
    mask1 = np.asarray(mask1, dtype=bool)
    mask2 = np.asarray(mask2, dtype=bool)

    intersection = np.logical_and(mask1, mask2).sum()
    union = np.logical_or(mask1, mask2).sum()

    if union == 0:
        return 1.0 if intersection == 0 else 0.0

    return intersection / union

num_images_to_visualize = 5
processed_image_count = 0
subset_iou_scores = []

print(f"\nİlk {num_images_to_visualize} Resim İçin Maske Karşılaştırması ve IoU Dğerleri (Hesaplanan Eşik: {optimal_threshold:.4f} İle):")

# Saklanan prediction batch listesi üzerinde döngü yap
for batch_item in all_predictions_batches:
    batch_size = len(batch_item.image_path)

    for j in range(batch_size):
        if processed_image_count >= num_images_to_visualize:
            break

        current_image_path = batch_item.image_path[j]
        current_gt_mask_tensor = batch_item.gt_mask[j] if batch_item.gt_mask is not None and j < len(batch_item.gt_mask) else None
        current_anomaly_map_tensor = batch_item.anomaly_map[j] if batch_item.anomaly_map is not None and j < len(batch_item.anomaly_map) else None

        try:
            anomaly_map_np = current_anomaly_map_tensor.squeeze().cpu().numpy()
            ground_truth_mask_np = current_gt_mask_tensor.squeeze().cpu().numpy() if current_gt_mask_tensor is not None else np.zeros_like(anomaly_map_np)
        except Exception as e:
            print(f"Hata: Resim {processed_image_count + 1} ({os.path.basename(current_image_path)}) tensorları numpy'ye çevirirken hata oluştu: {e}. Atlanıyor.")
            continue

        ground_truth_mask_binary = ground_truth_mask_np > 0

        smoothed_map_np = cv2.GaussianBlur(anomaly_map_np, (5, 5), 0)

        predicted_mask_binary = smoothed_map_np > optimal_threshold

        iou = -1
        if current_gt_mask_tensor is not None:
             try:
                iou = calculate_iou(ground_truth_mask_binary, predicted_mask_binary)
                subset_iou_scores.append(iou)
                print(f"Resim {processed_image_count + 1} ({os.path.basename(current_image_path)}): IoU = {iou:.4f}")
             except Exception as e:
                print(f"Hata: Resim {processed_image_count + 1} ({os.path.basename(current_image_path)}) için IoU hesaplarken hata oluştu: {e}.")
                continue

        else:
             print(f"Resim {processed_image_count + 1} ({os.path.basename(current_image_path)}): GT Maske Yok. IoU Hesaplanmadı.")


        fig, axes = plt.subplots(1, 3, figsize=(18, 6))

        try:
            original_image_pil = Image.open(current_image_path).convert("RGB")
            axes[0].imshow(original_image_pil)
            axes[0].set_title("Orijinal Görüntü")
            axes[0].axis('off')
        except Exception as e:
            print(f"Hata: Resim {processed_image_count + 1} ({current_image_path}) yüklenirken hata oluştu: {e}. Gösterilemiyor.")
            axes[0].set_title("Görüntü Yükleme Hatası")
            axes[0].axis('off')

        axes[1].imshow(ground_truth_mask_binary, cmap='gray')
        axes[1].set_title("Ground Truth Maskesi" if current_gt_mask_tensor is not None else "GT Maske Yok")
        axes[1].axis('off')

        axes[2].imshow(predicted_mask_binary, cmap='gray')
        axes[2].set_title(f"Tahmin Edilen Maske\n(Eşik: {optimal_threshold:.4f})")
        axes[2].axis('off')

        main_title = f"Resim {processed_image_count + 1} ({os.path.basename(current_image_path)})"
        if iou != -1:
            main_title += f" - IoU: {iou:.4f}"
        plt.suptitle(main_title, fontsize=14)
        plt.tight_layout(rect=[0, 0.03, 1, 0.93])
        plt.show()

        processed_image_count += 1

    if processed_image_count >= num_images_to_visualize:
        break

if subset_iou_scores:
      average_iou_subset = sum(subset_iou_scores) / len(subset_iou_scores)
      print(f"\nGösterilen {len(subset_iou_scores)} Maskeli Resim İçin Ortalama IoU: {average_iou_subset:.4f}")
else:
      print("\nHiçbir maskeli resim başarıyla işlenemedi veya gösterilecek yeterli maskeli resim bulunamadı.")
# Out:
# WARNING:anomalib.engine.engine:ckpt_path is not provided. Model weights will not be loaded.
# INFO:pytorch_lightning.utilities.rank_zero:The following callbacks returned in `LightningModule.configure_callbacks` will override existing callbacks passed to Trainer: Evaluator, ImageVisualizer, PostProcessor, PreProcessor
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting: |          | 0/? [00:00<?, ?it/s]
# F1AdaptiveThreshold ile Hesaplanan Optimal Piksel Eşiği: 0.5219
#
# İlk 5 Resim İçin Maske Karşılaştırması ve IoU Dğerleri (Hesaplanan Eşik: 0.5219 İle):
# Resim 1 (100000003.jpg): IoU = 0.3605
# Resim 2 (100000006.jpg): IoU = 0.0790
# Resim 3 (100000008.jpg): IoU = 0.0974
# Resim 4 (100000009.jpg): IoU = 0.2034
# Resim 5 (100000012.jpg): IoU = 0.0000
# Gösterilen 5 Maskeli Resim İçin Ortalama IoU: 0.1480

# %%
all_iou_scores = []

for batch_item in all_predictions_batches:
    batch_size = len(batch_item.image_path)

    for j in range(batch_size):
        current_gt_mask_tensor = batch_item.gt_mask[j] if batch_item.gt_mask is not None and j < len(batch_item.gt_mask) else None
        current_anomaly_map_tensor = batch_item.anomaly_map[j] if batch_item.anomaly_map is not None and j < len(batch_item.anomaly_map) else None

        if current_gt_mask_tensor is None or current_anomaly_map_tensor is None:
            continue

        try:
            anomaly_map_np = current_anomaly_map_tensor.squeeze().cpu().numpy()
            ground_truth_mask_np = current_gt_mask_tensor.squeeze().cpu().numpy()
        except Exception as e:
            print(f"Hata: Tensorları numpy'ye çevirirken hata oluştu: {e}. Atlanıyor.")
            continue

        ground_truth_mask_binary = ground_truth_mask_np > 0
        smoothed_map_np = cv2.GaussianBlur(anomaly_map_np, (5, 5), 0)
        predicted_mask_binary = smoothed_map_np > optimal_threshold

        try:
            iou = calculate_iou(ground_truth_mask_binary, predicted_mask_binary)
            all_iou_scores.append(iou)
        except Exception as e:
            print(f"IoU hesaplanırken hata oluştu: {e}.")
            continue

if all_iou_scores:
    overall_average_iou = sum(all_iou_scores) / len(all_iou_scores)
    print(f"\nTüm Resimler İçin Ortalama IoU: {overall_average_iou:.4f}")
else:
    print("\nHiçbir resim başarıyla işlenemedi. Ortalama IoU hesaplanamadı.")
# Out:
# Tüm Resimler İçin Ortalama IoU: 0.3599
